# %% [markdown]
# # GOAT Researcher CVE Quantity

# %% [markdown]
# ## Setup

# %%
import pathlib
import pandas
import json
data = pathlib.Path('..','..','cvedata','data', 'researcher_cve_map.json')
df = pandas.read_json(data)
df.head()

# %%
df[1] = df[1].apply(len)

# %% [markdown]
# ## Top 25 Table

# %%
df.head(25)
# Out:
#                       0    1
# 0             yuki chen  357
# 1         zhiniang peng  250
# 2       mateusz jurczyk  204
# 3         james forshaw  123
# 4            xuefeng li  106
# 5           david erceg   93
# 6          khalil zhani   91
# 7             lokihardt   84
# 8                  kdot   84
# 9            qixun zhao   78
# 10          jun kokatsu   70
# 11           guang gong   70
# 12              miaubiz   68
# 13          ashar javed   66
# 14                k0shl   65
# 15          fangming gu   65
# 16  dhanesh kizhakkinan   60
# 17        steven seeley   59
# 18             zhong_sf   58
# 19             yangkang   57
# 20          huynh phuoc   56
# 21        hossein lotfi   56
# 22                pgboy   50
# 23          jarvis_1oop   50
# 24         nicolas joly   47

# %% [markdown]
# ## Top 25 Chart

# %%
df.set_index(0)[:25].plot(kind='bar',y=1,ylabel='CVE Count',xlabel='Researcher')
# Out:
# <AxesSubplot: xlabel='Researcher', ylabel='CVE Count'>
